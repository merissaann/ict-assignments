# %% [markdown]
# <a href="https://colab.research.google.com/github/merissaann/ict-assignments/blob/main/Casestudy_supervised_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing necessary libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc,f1_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
df = pd.read_csv('/content/Training_data.csv')
df_test = pd.read_csv('/content/Testing_data.csv')

# %% [markdown]
# Understanding the data

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9509-MPYOD  Female              0      No         No      35          Yes
# 1  7746-AWNQW  Female              0      No         No      28           No
# 2  2208-UGTGR    Male              0      No         No      56          Yes
# 3  4884-LEVMQ    Male              0     Yes         No      39          Yes
# 4  6682-VCIXC  Female              0     Yes        Yes      43           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0                No              No  No internet service  ...
# 1  No phone service             DSL                   No  ...
# 2               Yes     Fiber optic                   No  ...
# 3                No              No  No internet service  ...
# 4  No phone service             DSL                  NaN  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# 1                  Yes                  Yes                   No
# 2                   No                   No                  Yes
# 3  No internet service  No internet service  No internet service
# 4                   No                  Yes                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0  No internet service        One year               No
# 1                   No  Month-to-month              Yes
# 2                  Yes  Month-to-month               No
# 3  No internet service        Two year              Yes
# 4                   No        One year              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0               Mailed check          20.75        700.45    No
# 1               Mailed check          35.75         961.4    No
# 2           Electronic check          98.60       5581.05    No
# 3  Bank transfer (automatic)          20.45           790    No
# 4  Bank transfer (automatic)          51.25        2151.6    No
#
# [5 rows x 21 columns]

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9509-MPYOD  Female              0      No         No      35          Yes
# 1  7746-AWNQW  Female              0      No         No      28           No
# 2  2208-UGTGR    Male              0      No         No      56          Yes
# 3  4884-LEVMQ    Male              0     Yes         No      39          Yes
# 4  6682-VCIXC  Female              0     Yes        Yes      43           No
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0                No              No  No internet service  ...
# 1  No phone service             DSL                   No  ...
# 2               Yes     Fiber optic                   No  ...
# 3                No              No  No internet service  ...
# 4  No phone service             DSL                  NaN  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# 1                  Yes                  Yes                   No
# 2                   No                   No                  Yes
# 3  No internet service  No internet service  No internet service
# 4                   No                  Yes                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0  No internet service        One year               No
# 1                   No  Month-to-month              Yes
# 2                  Yes  Month-to-month               No
# 3  No internet service        Two year              Yes
# 4                   No        One year              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0               Mailed check          20.75        700.45    No
# 1               Mailed check          35.75         961.4    No
# 2           Electronic check          98.60       5581.05    No
# 3  Bank transfer (automatic)          20.45           790    No
# 4  Bank transfer (automatic)          51.25        2151.6    No
#
# [5 rows x 21 columns]

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5194  6331-LWDTQ    Male              0      No         No      10
# 4079  7892-POOKP  Female              0     Yes         No      28
# 2717  5995-SNNEW    Male              1     Yes         No      23
# 4628  2418-TPEUN  Female              0     Yes        Yes      56
# 1606  3096-WPXBT  Female              0     Yes        Yes      61
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 5194          Yes           Yes             DSL                   No  ...
# 4079          Yes           Yes     Fiber optic                   No  ...
# 2717          Yes           Yes     Fiber optic                   No  ...
# 4628          Yes            No              No  No internet service  ...
# 1606          Yes           Yes     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 5194                   No                   No                  Yes
# 4079                  Yes                  Yes                  Yes
# 2717                  Yes                   No                  Yes
# 4628  No internet service  No internet service  No internet service
# 1606                  Yes                   No                   No
#
#           StreamingMovies        Contract PaperlessBilling  \
# 5194                  Yes  Month-to-month              Yes
# 4079                  Yes  Month-to-month              Yes
# 2717                  Yes  Month-to-month              Yes
# 4628  No internet service        Two year              Yes
# 1606                  Yes        One year              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 5194  Credit card (automatic)          72.15        794.25   Yes
# 4079         Electronic check         104.80       3046.05   Yes
# 2717         Electronic check         104.45       2184.85    No
# 4628  Credit card (automatic)          19.80        1119.9    No
# 1606  Credit card (automatic)         100.70       6018.65    No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5634 entries, 0 to 5633
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   object
#  1   gender            5465 non-null   object
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   object
#  4   Dependents        5634 non-null   object
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   object
#  7   MultipleLines     5634 non-null   object
#  8   InternetService   5634 non-null   object
#  9   OnlineSecurity    5465 non-null   object
#  10  OnlineBackup      5634 non-null   object
#  11  DeviceProtection  5634 non-null   object
#  12  TechSupport       5634 non-null   object
#  13  StreamingTV       5634 non-null   object
#  14  StreamingMovies   5634 non-null   object
#  15  Contract          5634 non-null   object
#  16  PaperlessBilling  5634 non-null   object
#  17  PaymentMethod     5634 non-null   object
#  18  MonthlyCharges    5240 non-null   float64
#  19  TotalCharges      5353 non-null   object
#  20  Churn             5634 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 924.5+ KB

# %%
df['TotalCharges'] = df['TotalCharges'].replace(" ", float('nan')).astype(float)
df_test['TotalCharges'] = df_test['TotalCharges'].replace(" ", float('nan')).astype(float)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.isna().sum()
# Out:
# customerID            0
# gender              169
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines         0
# InternetService       0
# OnlineSecurity      169
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges      394
# TotalCharges        290
# Churn                 0
# dtype: int64

# %%
df['gender'].fillna(df['gender'].mode()[0], inplace=True)
df['OnlineSecurity'].fillna(df['OnlineSecurity'].mode()[0], inplace=True)
df['TotalCharges'].fillna(df['TotalCharges'].mode()[0], inplace=True)
# Out:
# <ipython-input-45-a210b873ac53>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].fillna(df['gender'].mode()[0], inplace=True)
# <ipython-input-45-a210b873ac53>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['OnlineSecurity'].fillna(df['OnlineSecurity'].mode()[0], inplace=True)
# <ipython-input-45-a210b873ac53>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['TotalCharges'].fillna(df['TotalCharges'].mode()[0], inplace=True)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df['MonthlyCharges'].fillna(df['MonthlyCharges'].median(), inplace=True)
# Out:
# <ipython-input-47-0acd1b5afdf9>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MonthlyCharges'].fillna(df['MonthlyCharges'].median(), inplace=True)

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_test.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        2
# Churn               0
# dtype: int64

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    5634.000000  5634.000000     5634.000000   5634.000000
# mean        0.159744    32.606851       65.490034   2167.382428
# std         0.366401    24.614976       29.020760   2263.594869
# min         0.000000     0.000000       18.250000     18.850000
# 25%         0.000000     9.000000       44.000000    296.437500
# 50%         0.000000    29.000000       70.650000   1267.500000
# 75%         0.000000    56.000000       89.100000   3590.537500
# max         1.000000    72.000000      118.750000   8684.800000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for col in df.columns:
  unique_vals = df[col].unique()
  print(f"Column '{col}':")
  print(unique_vals)
  print(f"Total unique values: {len(unique_vals)}")
  print("-" * 20)
# Out:
# Column 'customerID':
# ['9509-MPYOD' '7746-AWNQW' '2208-UGTGR' ... '4277-BWBML' '9110-HSGTV'
#  '3402-XRIUO']
# Total unique values: 5634
# --------------------
# Column 'gender':
# ['Female' 'Male']
# Total unique values: 2
# --------------------
# Column 'SeniorCitizen':
# [0 1]
# Total unique values: 2
# --------------------
# Column 'Partner':
# ['No' 'Yes']
# Total unique values: 2
# --------------------
# Column 'Dependents':
# ['No' 'Yes']
# Total unique values: 2
# --------------------
# Column 'tenure':
# [35 28 56 39 43  2 18 63 40 53 48 72 61  6 21  9  3 58 57 17 30 20  4 16
#  71 38  5 13 55 60 37  1  7 11 12 67 54  8 22 65 36 50 23 49 69 70 25 14
#  10 52 68 33 24 66 59 32 27 29 45 42 64 62 19 41 51 44 34 26 47 31 15 46
#   0]
# Total unique values: 73
# --------------------
# Column 'PhoneService':
# ['Yes' 'No']
# Total unique values: 2
# --------------------
# Column 'MultipleLines':
# ['No' 'No phone service' 'Yes']
# Total unique values: 3
# --------------------
# Column 'InternetService':
# ['No' 'DSL' 'Fiber optic']
# Total unique values: 3
# --------------------
# Column 'OnlineSecurity':
# ['No internet service' 'No' 'Yes']
# Total unique values: 3
# --------------------
# Column 'OnlineBackup':
# ['No internet service' 'No' 'Yes']
# Total unique values: 3
# --------------------
# Column 'DeviceProtection':
# ['No internet service' 'Yes' 'No']
# Total unique values: 3
# --------------------
# Column 'TechSupport':
# ['No internet service' 'Yes' 'No']
# Total unique values: 3
# --------------------
# Column 'StreamingTV':
# ['No internet service' 'No' 'Yes']
# Total unique values: 3
# --------------------
# Column 'StreamingMovies':
# ['No internet service' 'No' 'Yes']
# Total unique values: 3
# --------------------
# Column 'Contract':
# ['One year' 'Month-to-month' 'Two year']
# Total unique values: 3
# --------------------
# Column 'PaperlessBilling':
# ['No' 'Yes']
# Total unique values: 2
# --------------------
# Column 'PaymentMethod':
# ['Mailed check' 'Electronic check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Total unique values: 4
# --------------------
# Column 'MonthlyCharges':
# [20.75 35.75 98.6  ... 39.85 63.05 41.95]
# Total unique values: 1478
# --------------------
# Column 'TotalCharges':
# [ 700.45  961.4  5581.05 ... 1322.85 5555.3  1381.8 ]
# Total unique values: 5039
# --------------------
# Column 'Churn':
# ['No' 'Yes']
# Total unique values: 2
# --------------------

# %%
df = df.drop('customerID', axis=1)
df_test = df_test.drop('customerID', axis=1)

# %% [markdown]
# Graphical analysis

# %%
# Exclude 'MonthlyCharges', 'TotalCharges', and 'tenure'
columns_to_plot = [col for col in df.columns if col not in ['MonthlyCharges', 'TotalCharges', 'tenure']]

# Iterate through the selected columns
for col in columns_to_plot:
  value_counts = df[col].value_counts()

  # Create the pie chart
  plt.figure(figsize=(8, 8))
  plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=90)
  plt.title(f'Distribution of {col}')
  plt.axis('equal')
  plt.show()

# %%
# Select numerical columns excluding 'SeniorCitizen'
numerical_cols = df.select_dtypes(include=np.number).columns
numerical_cols = [col for col in numerical_cols if col != 'SeniorCitizen']

# Plot histograms for numerical columns
for col in numerical_cols:
  plt.figure(figsize=(8, 6))
  plt.hist(df[col], bins=20)
  plt.xlabel(col)
  plt.ylabel('Frequency')
  plt.title(f'Histogram of {col}')
  plt.show()

# %%
# Plot box plots for numerical columns
for col in numerical_cols:
  plt.figure(figsize=(8, 6))
  sns.boxplot(x=df[col])
  plt.xlabel(col)
  plt.title(f'Box Plot of {col}')
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Select numerical columns excluding 'SeniorCitizen'
numerical_cols_t = df_test.select_dtypes(include=np.number).columns
numerical_cols_t = [col for col in numerical_cols if col != 'SeniorCitizen']

# Plot box plots for numerical columns
for col in numerical_cols_t:
  plt.figure(figsize=(8, 6))
  sns.boxplot(x=df[col])
  plt.xlabel(col)
  plt.title(f'Box Plot of {col}')
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Create scatter plots for pairs of numerical columns
for i in range(len(numerical_cols)):
  for j in range(i + 1, len(numerical_cols)):
    col1 = numerical_cols[i]
    col2 = numerical_cols[j]
    plt.figure(figsize=(8, 6))
    plt.scatter(df[col1], df[col2])
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.title(f'Scatter Plot of {col1} vs {col2}')
    plt.show()

# %%
# Create a contingency table
gender_churn_table = pd.crosstab(df['gender'], df['Churn'])

# Create the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(gender_churn_table, annot=True, fmt="d", cmap="viridis")
plt.title("Heatmap of Gender vs Churn")
plt.xlabel("Churn")
plt.ylabel("Gender")
plt.show()

# %%
sns.pairplot(df, hue='Churn')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# Calculate the total charge per month
df['ChargePerMonth'] = df['TotalCharges'] / df['tenure']
df_test['ChargePerMonth'] = df_test['TotalCharges'] / df_test['tenure']

# Create a new feature for the interaction between tenure and monthly charges
df['TenureMonthlyCharges'] = df['tenure'] * df['MonthlyCharges']
df_test['TenureMonthlyCharges'] = df_test['tenure'] * df_test['MonthlyCharges']

# Create a new feature for the ratio of total charges to monthly charges
df['TotalMonthlyChargeRatio'] = df['TotalCharges'] / df['MonthlyCharges']
df_test['TotalMonthlyChargeRatio'] = df_test['TotalCharges'] / df_test['MonthlyCharges']

# Create a new feature for the difference between total charges and monthly charges
df['TotalMonthlyChargeDiff'] = df['TotalCharges'] - df['MonthlyCharges']
df_test['TotalMonthlyChargeDiff'] = df_test['TotalCharges'] - df_test['MonthlyCharges']

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0      No         No      35          Yes
# 1  Female              0      No         No      28           No
# 2    Male              0      No         No      56          Yes
# 3    Male              0     Yes         No      39          Yes
# 4  Female              0     Yes        Yes      43           No
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0                No              No  No internet service  No internet service
# 1  No phone service             DSL                   No                   No
# 2               Yes     Fiber optic                   No                  Yes
# 3                No              No  No internet service  No internet service
# 4  No phone service             DSL                   No                  Yes
#
#    ...        Contract PaperlessBilling              PaymentMethod  \
# 0  ...        One year               No               Mailed check
# 1  ...  Month-to-month              Yes               Mailed check
# 2  ...  Month-to-month               No           Electronic check
# 3  ...        Two year              Yes  Bank transfer (automatic)
# 4  ...        One year              Yes  Bank transfer (automatic)
#
#   MonthlyCharges TotalCharges Churn ChargePerMonth  TenureMonthlyCharges  \
# 0          20.75       700.45    No      20.012857                726.25
# 1          35.75       961.40    No      34.335714               1001.00
# 2          98.60      5581.05    No      99.661607               5521.60
# 3          20.45       790.00    No      20.256410                797.55
# 4          51.25      2151.60    No      50.037209               2203.75
#
#    TotalMonthlyChargeRatio TotalMonthlyChargeDiff
# 0                33.756627                 679.70
# 1                26.892308                 925.65
# 2                56.602941                5482.45
# 3                38.630807                 769.55
# 4                41.982439                2100.35
#
# [5 rows x 24 columns]

# %% [markdown]
# scaling

# %%
# Select numerical columns excluding 'SeniorCitizen'
numerical_cols = df.select_dtypes(include=np.number).columns
numerical_cols = [col for col in numerical_cols if col != 'SeniorCitizen']

# Initialize StandardScaler
scaler = StandardScaler()

# Replace infinite values with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df_test.replace([np.inf, -np.inf], np.nan, inplace=True)

# Impute NaN values with the mean of each column
df[numerical_cols] = df[numerical_cols].fillna(df[numerical_cols].mean())
df_test[numerical_cols] = df_test[numerical_cols].fillna(df_test[numerical_cols].mean())

# Fit and transform the numerical columns
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
df_test[numerical_cols] = scaler.transform(df_test[numerical_cols])

# %%
df.isna().sum()
# Out:
# gender                     0
# SeniorCitizen              0
# Partner                    0
# Dependents                 0
# tenure                     0
# PhoneService               0
# MultipleLines              0
# InternetService            0
# OnlineSecurity             0
# OnlineBackup               0
# DeviceProtection           0
# TechSupport                0
# StreamingTV                0
# StreamingMovies            0
# Contract                   0
# PaperlessBilling           0
# PaymentMethod              0
# MonthlyCharges             0
# TotalCharges               0
# Churn                      0
# ChargePerMonth             0
# TenureMonthlyCharges       0
# TotalMonthlyChargeRatio    0
# TotalMonthlyChargeDiff     0
# dtype: int64

# %% [markdown]
# Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# Initialize OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

# Assuming df and df_test are your dataframes and col is the column you're processing
df[col] = ordinal_encoder.fit_transform(df[col].values.reshape(-1, 1))
df_test[col] = ordinal_encoder.transform(df_test[col].values.reshape(-1, 1))

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0       0              0        0           0  0.097232             1
# 1       0              0        0           0 -0.187173             0
# 2       1              0        0           0  0.950447             1
# 3       1              0        1           0  0.259749             1
# 4       0              0        1           1  0.422266             0
#
#    MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0            0.0              No  No internet service  No internet service
# 1            1.0             DSL                   No                   No
# 2            2.0     Fiber optic                   No                  Yes
# 3            0.0              No  No internet service  No internet service
# 4            1.0             DSL                   No                  Yes
#
#    ...        Contract PaperlessBilling              PaymentMethod  \
# 0  ...        One year               No               Mailed check
# 1  ...  Month-to-month              Yes               Mailed check
# 2  ...  Month-to-month               No           Electronic check
# 3  ...        Two year              Yes  Bank transfer (automatic)
# 4  ...        One year              Yes  Bank transfer (automatic)
#
#   MonthlyCharges TotalCharges Churn ChargePerMonth  TenureMonthlyCharges  \
# 0      -1.541793    -0.648112    No      -1.288288             -0.702329
# 1      -1.024876    -0.532820    No      -0.845744             -0.579814
# 2       1.141008     1.508207    No       1.172683              1.435992
# 3      -1.552131    -0.608547    No      -1.280763             -0.670535
# 4      -0.490728    -0.006973    No      -0.360602             -0.043489
#
#    TotalMonthlyChargeRatio TotalMonthlyChargeDiff
# 0                 0.117032              -0.633106
# 1                -0.152519              -0.523618
# 2                 1.014174               1.504896
# 3                 0.308434              -0.593108
# 4                 0.440048              -0.000687
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (5634, 24)

# %%
# Calculate the correlation matrix only on numeric columns
corr_matrix = df.select_dtypes(include=['float64', 'int64']).corr()

# Plot the correlation matrix
plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']
X_train = X
y_train = y
X_test = df_test.drop('Churn', axis=1)
y_test = df_test['Churn']

# %% [markdown]
# LogisticRegression Model

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode target variable 'y_train' if it contains strings
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)

# Encode categorical features in 'X_train' and 'X_test'
for col in X_train.select_dtypes(include=['object']).columns:
    X_train[col] = label_encoder.fit_transform(X_train[col])
    X_test[col] = label_encoder.transform(X_test[col])

# Now you can fit the model
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87      1044
#            1       0.65      0.56      0.60       365
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
conf_mat = confusion_matrix(y_test, y_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Tune LogisticRegression Model

# %%
#use gridsearch for hyperparameter tuning
#define parameter grid
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] #REGULARISATION STRENGTGH
              ,'penalty': ['l1', 'l2'] #type of regularisation
              ,'solver': ['liblinear', 'saga'] #SOLVER
              }
#create logistic regression object
logreg = LogisticRegression(max_iter=1000)
#perform gridsearch
grid_search = GridSearchCV(logreg, param_grid, cv=5,scoring='accuracy')
grid_search.fit(X_train, y_train)
#print best parameters
print("Best parameters: ", grid_search.best_params_)
# Out:
# Best parameters:  {'C': 0.1, 'penalty': 'l2', 'solver': 'saga'}

# %%
best_logreg_mod = LogisticRegression(C=0.1,penalty='l2', solver='saga')
best_logreg_mod.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.1, solver='saga')

# %%
best_y_pred = best_logreg_mod.predict(X_test)

# %%
print(classification_report(y_test, best_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      1044
#            1       0.66      0.55      0.60       365
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.73      0.74      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
conf_mat = confusion_matrix(y_test, best_y_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# KNN

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86      1044
#            1       0.61      0.30      0.40       365
#
#     accuracy                           0.77      1409
#    macro avg       0.70      0.62      0.63      1409
# weighted avg       0.74      0.77      0.74      1409

# %%
conf_mat = confusion_matrix(y_test,y_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# KNN Tuning

# %%
param_grid = {
    'n_neighbors': list(range(1, 31)),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

print("Best parameters: ", grid_search.best_params_)
# Out:
# Best parameters:  {'metric': 'manhattan', 'n_neighbors': 28, 'weights': 'uniform'}

# %%
best_knn = KNeighborsClassifier(n_neighbors=28, weights='uniform', metric='manhattan')
best_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=28)

# %%
knn_y_pred = best_knn.predict(X_test)

# %%
print(classification_report(y_test, knn_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87      1044
#            1       0.63      0.55      0.59       365
#
#     accuracy                           0.80      1409
#    macro avg       0.74      0.72      0.73      1409
# weighted avg       0.79      0.80      0.79      1409

# %%
conf_mat = confusion_matrix(y_test,knn_y_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Decision Tree

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt_model.predict(X_test)

# %%
print(classification_report(y_test,dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82      1044
#            1       0.48      0.49      0.49       365
#
#     accuracy                           0.73      1409
#    macro avg       0.65      0.65      0.65      1409
# weighted avg       0.73      0.73      0.73      1409

# %%
conf_mat = confusion_matrix(y_test, dt_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# DecisionTree Tuning

# %%
tree = DecisionTreeClassifier()

# Set up the parameters grid
param_grid = {
    'criterion': ['gini', 'entropy'],  # Function to measure the quality of split
    'max_depth': [None, 10, 20, 30, 40, 50],  # Maximum depth of the tree
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required to be at a leaf node
}

# Perform grid search
grid_search = GridSearchCV(tree, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best parameters
print("Best Parameters for Decision Tree:", grid_search.best_params_)
# Out:
# Best Parameters for Decision Tree: {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10}

# %%
dtbest_model = DecisionTreeClassifier(criterion='entropy',max_depth=10,min_samples_leaf=2,min_samples_split=2)
dtbest_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=2)

# %%
dtbest_pred = dtbest_model.predict(X_test)

# %%
print(classification_report(y_test,dtbest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      1044
#            1       0.55      0.58      0.56       365
#
#     accuracy                           0.77      1409
#    macro avg       0.70      0.70      0.70      1409
# weighted avg       0.77      0.77      0.77      1409

# %%
conf_mat = confusion_matrix(y_test, dtbest_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Random Forest

# %%
# Create a Random Forest classifier
rf_model = RandomForestClassifier(random_state=42)

# Train the model
rf_model.fit(X_train, y_train)

# Make predictions on the test set
rf_pred = rf_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, rf_pred))
print(confusion_matrix(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1044
#            1       0.61      0.49      0.54       365
#
#     accuracy                           0.79      1409
#    macro avg       0.72      0.69      0.70      1409
# weighted avg       0.77      0.79      0.78      1409
#
# [[930 114]
#  [187 178]]

# %%
conf_mat = confusion_matrix(y_test, rf_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# SVM

# %%
svm_model = SVC()
svm_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
svm_pred = svm_model.predict(X_test)

# %%
print(classification_report(y_test, svm_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1044
#            1       0.68      0.48      0.57       365
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.70      0.72      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
conf_mat = confusion_matrix(y_test, svm_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# Ensemble Method

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC

# Define the models
logreg_model = LogisticRegression()
rf_model = RandomForestClassifier()
svc_model = SVC()  # Initialize the SVC model

# Create the ensemble model
ensemble_model = VotingClassifier(
    estimators=[
        ('lr', logreg_model),
        ('rf', rf_model),
        ('svc', svc_model)  # Now 'svc_model' is defined
    ],
    voting='hard'  # or 'soft' if you're using probabilities
)

# Fit the ensemble model
ensemble_model.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression()),
#                              ('rf', RandomForestClassifier()), ('svc', SVC())])

# %%
# Train the ensemble model
ensemble_model.fit(X_train, y_train)

# Make predictions
ensemble_pred = ensemble_model.predict(X_test)

# Evaluate the ensemble model
print(classification_report(y_test, ensemble_pred))
conf_mat = confusion_matrix(y_test, ensemble_pred)
plt.figure()
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Greens')
plt.title('Confusion Matrix')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.88      1044
#            1       0.67      0.51      0.58       365
#
#     accuracy                           0.81      1409
#    macro avg       0.75      0.71      0.73      1409
# weighted avg       0.80      0.81      0.80      1409

# %%
# LogisticRegression Model
y_pred = model.predict(X_test)
logreg_accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Accuracy: {logreg_accuracy:.5f}")

# Tuned LogisticRegression Model
best_y_pred = best_logreg_mod.predict(X_test)
best_logreg_accuracy = accuracy_score(y_test, best_y_pred)
print(f"Tuned Logistic Regression Accuracy: {best_logreg_accuracy:.5f}")

# KNN Model
knn_y_pred = best_knn.predict(X_test)
knn_accuracy = accuracy_score(y_test, knn_y_pred)
print(f"KNN Accuracy: {knn_accuracy:.5f}")

# Decision Tree Model
dtbest_pred = dtbest_model.predict(X_test)
dt_accuracy = accuracy_score(y_test, dtbest_pred)
print(f"Decision Tree Accuracy: {dt_accuracy:.5f}")

# Random Forest Model
rf_accuracy = accuracy_score(y_test, rf_pred)
print(f"Random Forest Accuracy: {rf_accuracy:.5f}")

# SVM Model
svm_accuracy = accuracy_score(y_test, svm_pred)
print(f"SVM Accuracy: {svm_accuracy:.5f}")

# Ensemble Model
ensemble_pred = ensemble_model.predict(X_test)
ensemble_accuracy = accuracy_score(y_test, ensemble_pred)
print(f"Ensemble Model Accuracy: {ensemble_accuracy:.5f}")
# Out:
# Logistic Regression Accuracy: 0.80908
# Tuned Logistic Regression Accuracy: 0.80979
# KNN Accuracy: 0.79915
# Decision Tree Accuracy: 0.76579
# Random Forest Accuracy: 0.78637
# SVM Accuracy: 0.80837
# Ensemble Model Accuracy: 0.80696

# %% [markdown]
# The best model is ensemble method with a accuracy of 81.40%
#
# Other than ensemble method the best model is Tuned Logistic Regression with a accuracy of 80.97%
#
# Then Svm model and Logistic Regression model with a accuracy of 80.84%
