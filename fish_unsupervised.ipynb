# %% [markdown]
# <a href="https://colab.research.google.com/github/merissaann/ict-assignments/blob/main/fish_unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/fish.csv')

# %%
df
# Out:
#     Bream   242.0  23.2  25.4  30.0  38.4  13.4
# 0   Bream   290.0  24.0  26.3  31.2  40.0  13.8
# 1   Bream   340.0  23.9  26.5  31.1  39.8  15.1
# 2   Bream   363.0  26.3  29.0  33.5  38.0  13.3
# 3   Bream   430.0  26.5  29.0  34.0  36.6  15.1
# 4   Bream   450.0  26.8  29.7  34.7  39.2  14.2
# ..    ...     ...   ...   ...   ...   ...   ...
# 79   Pike   950.0  48.3  51.7  55.1  16.2  11.2
# 80   Pike  1250.0  52.0  56.0  59.7  17.9  11.7
# 81   Pike  1600.0  56.0  60.0  64.0  15.0   9.6
# 82   Pike  1550.0  56.0  60.0  64.0  15.0   9.6
# 83   Pike  1650.0  59.0  63.4  68.0  15.9  11.0
#
# [84 rows x 7 columns]

# %%
df.describe()
# Out:
#              242.0       23.2       25.4       30.0       38.4       13.4
# count    84.000000  84.000000  84.000000  84.000000  84.000000  84.000000
# mean    434.017857  27.388095  29.607143  33.157143  27.953571  12.859524
# std     382.648669  11.348058  12.249630  13.272086  10.351142   2.129377
# min       0.000000   9.300000   9.800000  10.800000  14.500000   8.700000
# 25%     120.000000  19.325000  20.950000  23.550000  16.875000  10.875000
# 50%     390.000000  28.450000  30.850000  35.050000  26.900000  13.700000
# 75%     657.500000  32.725000  36.000000  40.675000  39.225000  14.700000
# max    1650.000000  59.000000  63.400000  68.000000  44.500000  16.100000

# %%
df.dtypes
# Out:
# Bream     object
# 242.0    float64
# 23.2     float64
# 25.4     float64
# 30.0     float64
# 38.4     float64
# 13.4     float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bream   84 non-null     object
#  1   242.0   84 non-null     float64
#  2   23.2    84 non-null     float64
#  3   25.4    84 non-null     float64
#  4   30.0    84 non-null     float64
#  5   38.4    84 non-null     float64
#  6   13.4    84 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 4.7+ KB

# %%
df.isna().sum()
# Out:
# Bream    0
# 242.0    0
# 23.2     0
# 25.4     0
# 30.0     0
# 38.4     0
# 13.4     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
numeric_cols = df.select_dtypes(include=['number']).columns
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

df.head()
# Out:
#    Bream     242.0      23.2      25.4      30.0      38.4      13.4
# 0  Bream -0.378631 -0.300355 -0.271601 -0.148349  1.170768  0.444320
# 1  Bream -0.247179 -0.309220 -0.255175 -0.155929  1.151330  1.058494
# 2  Bream -0.186710 -0.096460 -0.049862  0.025988  0.976392  0.208099
# 3  Bream -0.010563 -0.078730 -0.049862  0.063887  0.840329  1.058494
# 4  Bream  0.042018 -0.052135  0.007626  0.116946  1.093017  0.633297

# %%
for col in df.columns:
  sns.boxplot(df[col])
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# ...

# %%
df.head()
# Out:
#    Bream     242.0      23.2      25.4      30.0      38.4      13.4
# 0  Bream -0.378631 -0.300355 -0.271601 -0.148349  1.170768  0.444320
# 1  Bream -0.247179 -0.309220 -0.255175 -0.155929  1.151330  1.058494
# 2  Bream -0.186710 -0.096460 -0.049862  0.025988  0.976392  0.208099
# 3  Bream -0.010563 -0.078730 -0.049862  0.063887  0.840329  1.058494
# 4  Bream  0.042018 -0.052135  0.007626  0.116946  1.093017  0.633297

# %%
feature_cols =['242.0','23.2','25.4','30.0']
for col in feature_cols:
  Q1 = df[col].quantile(0.25)
  Q2 = df[col].quantile(0.50)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  lb = Q1 - 1.5*IQR
  ub = Q3 + 1.5*IQR
  df[col] = df[col].clip(lb,ub)
for col in feature_cols:
  sns.boxplot(df[col])
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
df['Bream'].unique()
# Out:
# array(['Bream', 'Roach', 'Smelt', 'Pike'], dtype=object)

# %%
from sklearn.cluster import KMeans
import pandas as pd

numerical_df = df.select_dtypes(include=['number'])

wcss = []
cluster_range = range(1, 11)

for k in cluster_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(numerical_df)
    wcss.append(kmeans.inertia_)

# %%
pred_clusters = kmeans.predict(numerical_df)
pred_clusters
# Out:
# array([4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        8, 8, 8, 8, 0, 0, 0, 0, 0, 0, 0, 6, 6, 6, 6, 1, 6, 6, 6, 1, 1, 1,
#        6, 1, 1, 6, 1, 1, 1, 1, 1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 6,
#        3, 2, 2, 2, 2, 2, 2, 7, 7, 7, 7, 7, 7, 5, 5, 9, 9, 9], dtype=int32)

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['13.4'],df['23.2'],c=pred_clusters,cmap='rainbow',s=50)
centroids = kmeans.cluster_centers_
plt.title('K Means Clustering')
plt.xlabel('13.4')
plt.ylabel('23.2')
# Out:
# Text(0, 0.5, '23.2')

# %%
from sklearn.cluster import AgglomerativeClustering
agglo_clustering = AgglomerativeClustering(metric='euclidean', linkage='ward')
y_agglo = agglo_clustering.fit_predict(numerical_df )

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['13.4'],df['23.2'],c=y_agglo,cmap='rainbow',s=50)
centroids = kmeans.cluster_centers_
plt.scatter(centroids[:,0],centroids[:,1],c='black',s=200,alpha=0.5)
plt.title('Agglomerative Clusturing')
plt.xlabel('13.4')
plt.ylabel('23.2')
# Out:
# Text(0, 0.5, '23.2')

# %%
from sklearn.metrics import silhouette_score
sillhouette_score = silhouette_score(numerical_df,y_agglo)
sillhouette_score
# Out:
# 0.4177428344307579

# %%
silh_score = []
for i in range(2,11):
  agglo_clustering = AgglomerativeClustering(n_clusters=i,metric='euclidean', linkage='ward')
  agglo_labels = agglo_clustering.fit_predict(numerical_df)
  score = silhouette_score(numerical_df,agglo_labels)
  silh_score.append(score)
  print(f'Silhouette score for {i} clusters is {score}')
# Out:
# Silhouette score for 2 clusters is 0.4177428344307579
# Silhouette score for 3 clusters is 0.5169147720889677
# Silhouette score for 4 clusters is 0.5523642867101494
# Silhouette score for 5 clusters is 0.583914371276057
# Silhouette score for 6 clusters is 0.5011467402968541
# Silhouette score for 7 clusters is 0.4882869290716089
# Silhouette score for 8 clusters is 0.46468801262506315
# Silhouette score for 9 clusters is 0.46252752873502634
# Silhouette score for 10 clusters is 0.44697261835423163

# %%
plt.plot(range(2,11),silh_score,marker = 'o')
plt.title('Silhouette Score')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.show()
